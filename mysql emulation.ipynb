# %%
# !pip install mysql.connector

# %% [markdown]
# Loading the Datasets

# %%
import pandas as pd
df12 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/foreclosed.csv', index_col=False, delimiter = ',')
df1 = pd.DataFrame(df12)
df22 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/crime_data2.csv', index_col=False, delimiter = ',')
df2 = pd.DataFrame(df22)

# %%
df12.fillna(0)
df12 = df12.where((pd.notnull(df12)), None)
# df22.fillna(0)
# df22 = df22.where((pd.notnull(df22)), None)

# %%
df12.head()
# Out:
#    Unnamed: 0         APN Registered Date       Property Type  \
# 0           0  2004019019      10/28/2019       Single Family
# 1           1  2134029009      06/07/2019       Single Family
# 2           2  2163016017      11/05/2019       Single Family
# 3           3  2378026016      04/10/2019  Vacant Residential
# 4           4  2376001011      10/28/2019       Single Family
#
#      Property Address Property City Property State  Property Zip  Longitude  \
# 0  8560 N RUDNICK AVE   LOS ANGELES             CA         93063 -118.61291
# 1  6452 N JUMILLA AVE   LOS ANGELES             CA         91367 -118.56314
# 2  19255 W REDWING ST   LOS ANGELES             CA         91356 -118.55295
# 3   11258 W LAURIE DR   LOS ANGELES             CA         91604 -118.37539
# 4  4148 N SUNSWEPT DR   LOS ANGELES             CA         91604 -118.40584
#
#    Latitude                       Property on Map
# 0  34.22684           POINT (-118.61291 34.22684)
# ...

# %%
df22.head()
# Out:
#    ID      DR_NO                DATE OCC  AREA  AREA NAME  Rpt Dist No  \
# 0   0  140113642  06/02/2014 12:00:00 AM     1    Central          142
# 1   1  142015449  03/01/2014 12:00:00 AM    20    Olympic         2015
# 2   2  140318666  08/25/2014 12:00:00 AM     3  Southwest          392
# 3   3  140207314  03/05/2014 12:00:00 AM     2    Rampart          219
# 4   4  141304259  01/03/2014 12:00:00 AM    13     Newton         1307
#
#    Crm Cd               Crm Cd Desc  Premis Cd  \
# 0     330     BURGLARY FROM VEHICLE      123.0
# 1     354         THEFT OF IDENTITY      501.0
# 2     624  BATTERY - SIMPLE ASSAULT      501.0
# 3     354         THEFT OF IDENTITY      218.0
# 4     624  BATTERY - SIMPLE ASSAULT      502.0
#
#                                     Premis Desc  Weapon Used Cd  Crm Cd 1  \
# 0                  PARKING UNDERGROUND/BUILDING             0.0     330.0
# 1                        SINGLE FAMILY DWELLING             0.0     354.0
# ...

# %%
df12.dtypes
# Out:
# Unnamed: 0            int64
# APN                   int64
# Registered Date      object
# Property Type        object
# Property Address     object
# Property City        object
# Property State       object
# Property Zip          int64
# Longitude           float64
# Latitude            float64
# Property on Map      object
# dtype: object

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as connection

# %% [markdown]
# Seeing if we are connected and fetching all databases: like SHOW DATABASES in SQL

# %%
import mysql.connector as mysql

db = mysql.connect(
    host = "localhost",
    user = "root",
    passwd = "Rudrax@799"
)

cursor = db.cursor()

cursor.execute("SHOW DATABASES")

databases = cursor.fetchall() ## it returns a list of all databases present

print(databases)

## showing one by one database
for database in databases:
    print(database)
# Out:
# [('crime_data',), ('crimedata',), ('foreclosed',), ('foreclosed1',), ('information_schema',), ('mysql',), ('newschema',), ('newschemascd',), ('performance_schema',), ('property',), ('sakila',), ('sys',), ('world',)]
# ('crime_data',)
# ('crimedata',)
# ('foreclosed',)
# ('foreclosed1',)
# ('information_schema',)
# ('mysql',)
# ('newschema',)
# ('newschemascd',)
# ('performance_schema',)
# ('property',)
# ('sakila',)
# ('sys',)
# ('world',)

# %% [markdown]
# Creating TABLE for FORECLOSED DATA

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = msql.connect(host='localhost', user='root',  
                        password='Rudrax@799')#give ur username, password
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("CREATE DATABASE foreclosed")
        print("Database is created")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Error while connecting to MySQL 1007 (HY000): Can't create database 'foreclosed'; database exists

# %% [markdown]
# Filling with 0 at Null, Nan valued positions

# %%
df12.replace('nan', None)
df12.fillna(0)
# Out:
#       Unnamed: 0         APN Registered Date       Property Type  \
# 0              0  2004019019      10/28/2019       Single Family
# 1              1  2134029009      06/07/2019       Single Family
# 2              2  2163016017      11/05/2019       Single Family
# 3              3  2378026016      04/10/2019  Vacant Residential
# 4              4  2376001011      10/28/2019       Single Family
# ...          ...         ...             ...                 ...
# 3312        3312  5109025013      10/05/2019        Multi-Family
# 3313        3313  2254017035      10/04/2019       Single Family
# 3314        3314  4352011010      04/07/2019       Single Family
# 3315        3315  6018027012      08/30/2019       Single Family
# 3316        3316  2617004047      01/07/2019       Single Family
#
#         Property Address Property City Property State  Property Zip  \
# 0     8560 N RUDNICK AVE   LOS ANGELES             CA         93063
# ...

# %% [markdown]
# Creating the Table with SQL CREATE TABLE FORMAT and giving values assigning each to load records form CSV

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', database='foreclosed', user='root', password='Rudrax@799')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS foreclose_data;')
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
        cursor.execute("CREATE TABLE foreclose_data(ID varchar(255),APN varchar(255),R_Date varchar(255),P_Type varchar(255),P_Address varchar(255),P_City varchar(255),P_State varchar(255),P_Zip int,Longitude varchar(255),Latitude varchar(255),P_Map varchar(255))")
        print("Table is created....")
        #loop through the data frame
        for i,row in df12.iterrows():
            #here %S means string values 
            sql = "INSERT INTO foreclosed.foreclose_data VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('foreclosed',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %% [markdown]
# Running and testing Queries on the dataset

# %%
# Execute query
sql = "SELECT * FROM foreclosed.foreclose_data"
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# ('0', '2004019019', '10/28/2019', 'Single Family', '8560 N RUDNICK AVE', 'LOS ANGELES', 'CA', 93063, '-118.61291', '34.22684', 'POINT (-118.61291 34.22684)')
# ('1', '2134029009', '06/07/2019', 'Single Family', '6452 N JUMILLA AVE', 'LOS ANGELES', 'CA', 91367, '-118.56314', '34.18823', 'POINT (-118.56314 34.18823)')
# ('2', '2163016017', '11/05/2019', 'Single Family', '19255 W REDWING ST', 'LOS ANGELES', 'CA', 91356, '-118.55295', '34.17097', 'POINT (-118.55295 34.17097)')
# ('3', '2378026016', '04/10/2019', 'Vacant Residential', '11258 W LAURIE DR', 'LOS ANGELES', 'CA', 91604, '-118.37539', '34.13644', 'POINT (-118.37539000000001 34.13644)')
# ('4', '2376001011', '10/28/2019', 'Single Family', '4148 N SUNSWEPT DR', 'LOS ANGELES', 'CA', 91604, '-118.40584', '34.14129', 'POINT (-118.40584 34.14129)')
# ('5', '2403008013', '08/09/2019', 'Non-Residential', '0', '0', 'CA', 0, '0.0', '0.0', '0')
# ...

# %%
sql2 = "SELECT * FROM foreclosed.foreclose_data LIMIT 10"
cursor.execute(sql2)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# ('0', '2004019019', '10/28/2019', 'Single Family', '8560 N RUDNICK AVE', 'LOS ANGELES', 'CA', 93063, '-118.61291', '34.22684', 'POINT (-118.61291 34.22684)')
# ('1', '2134029009', '06/07/2019', 'Single Family', '6452 N JUMILLA AVE', 'LOS ANGELES', 'CA', 91367, '-118.56314', '34.18823', 'POINT (-118.56314 34.18823)')
# ('2', '2163016017', '11/05/2019', 'Single Family', '19255 W REDWING ST', 'LOS ANGELES', 'CA', 91356, '-118.55295', '34.17097', 'POINT (-118.55295 34.17097)')
# ('3', '2378026016', '04/10/2019', 'Vacant Residential', '11258 W LAURIE DR', 'LOS ANGELES', 'CA', 91604, '-118.37539', '34.13644', 'POINT (-118.37539000000001 34.13644)')
# ('4', '2376001011', '10/28/2019', 'Single Family', '4148 N SUNSWEPT DR', 'LOS ANGELES', 'CA', 91604, '-118.40584', '34.14129', 'POINT (-118.40584 34.14129)')
# ('5', '2403008013', '08/09/2019', 'Non-Residential', '0', '0', 'CA', 0, '0.0', '0.0', '0')
# ...

# %%
sql3 = "SELECT * FROM foreclosed.foreclose_data WHERE P_Zip = 90007"
cursor.execute(sql3)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# ('62', '5054018015', '06/10/2019', 'Single Family', '2320 S RAYMOND AVE', 'LOS ANGELES', 'CA', 90007, '-118.29741', '34.03478', 'POINT (-118.29741000000001 34.03478)')
# ('264', '5075032011', '05/29/2019', 'Multi-Family', '2011 S RAYMOND AVE', 'LOS ANGELES', 'CA', 90007, '-118.29763', '34.0378', 'POINT (-118.29762999999998 34.0378)')
# ('747', '5055020012', '10/16/2019', 'Multi-Family', '1185 1/2 W 24TH ST', 'LOS ANGELES', 'CA', 90007, '-118.28611', '34.03449', 'POINT (-118.28611000000001 34.03449)')
# ('1175', '5075032011', '04/23/2019', 'Multi-Family', '2011 S RAYMOND AVE', 'LOS ANGELES', 'CA', 90007, '-118.29763', '34.0378', 'POINT (-118.29762999999998 34.0378)')
# ('1186', '5054010013', '01/15/2019', 'Multi-Family', '2658 S KENWOOD AVE', 'LOS ANGELES', 'CA', 90007, '-118.299', '34.03105', 'POINT (-118.299 34.03105)')
# ('1434', '5054026014', '11/07/2019', 'Multi-Family', '1459 W 25TH ST', 'LOS ANGELES', 'CA', 90007, '-118.2934', '34.03377', 'POINT (-118.2934 34.03377)')
# ...

# %%
import sqlalchemy
import pymysql
pymysql.install_as_MySQLdb()
import pandas as pd
my_conn = sqlalchemy.create_engine("mysql+mysqldb://root:Rudrax@799@localhost/dsci551")
# # print("connecting with engine " + str(my_conn)
# # connection = my_conn.connect()
# query = "select * from foreclosed.foreclose_data"
# df = pd.read_sql_query(query, connection)

                         
#                          >>> beers.to_sql('mybeers', my_conn, index=False)
# >>> # this will create a table called mybeers with content
# in beers
# 4

# %%
# !pip install ipython-sql
# %load_ext sql
# %sql sqlite://

print("connecting with engine " + str(conn))
# Out:
# ...
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# connecting with engine <mysql.connector.connection_cext.CMySQLConnection object at 0x000001630FE5BD60>

# %%
# %%sql
# select * from foreclose_data;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such table: foreclose_data
# [SQL: select * from foreclose_data;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
import sqlalchemy

# %% [markdown]
# Repeating the same as above with Crime_data table and using Crime Data CSV file to SQL

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = msql.connect(host='localhost', user='root',  
                        password='Rudrax@799')#give ur username, password
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("CREATE DATABASE crime_data")
        print("Database is created")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Error while connecting to MySQL 1007 (HY000): Can't create database 'crime_data'; database exists

# %%
df22.replace('nan', 0)
df22.fillna(0)
# Out:
#             ID      DR_NO                DATE OCC  AREA   AREA NAME  \
# 0            0  140113642  06/02/2014 12:00:00 AM     1     Central
# 1            1  142015449  03/01/2014 12:00:00 AM    20     Olympic
# 2            2  140318666  08/25/2014 12:00:00 AM     3   Southwest
# 3            3  140207314  03/05/2014 12:00:00 AM     2     Rampart
# 4            4  141304259  01/03/2014 12:00:00 AM    13      Newton
# ...        ...        ...                     ...   ...         ...
# 11995  1099373  190619736  09/26/2019 12:00:00 AM     6   Hollywood
# 11996  1099374  220407189  09/21/2019 12:00:00 AM     4  Hollenbeck
# 11997  1099375  191819991  09/20/2019 12:00:00 AM    18   Southeast
# 11998  1099376  190517435  10/27/2019 12:00:00 AM     5      Harbor
# 11999  1099377  190217729  09/01/2019 12:00:00 AM     2     Rampart
#
#        Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# ...

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', database='crime_data', user='root', password='Rudrax@799')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS crime_data;')
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
        cursor.execute("CREATE TABLE crime_data(ID varchar(255),DR_NO varchar(255),Date_occ varchar(255),Area varchar(255),Area_name varchar(255),Dist_no int,crmcd varchar(255),crmcdds varchar(255),premis varchar(255),premisdsc varchar(255),Weapons varchar(255),crmcd1 varchar(255),Location varchar(255),cross_st varchar(255),latitude varchar(255),longitude varchar(255))")
        print("Table is created....")
        #loop through the data frame
        for i,row in df22.iterrows():
            #here %S means string values 
            sql = "INSERT INTO crime_data.crime_data VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('crime_data',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
# Execute query
sql = "SELECT * FROM crime_data.crime_data"
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# ('0', '140113642', '06/02/2014 12:00:00 AM', '1', 'Central', 142, '330', 'BURGLARY FROM VEHICLE', '123.0', 'PARKING UNDERGROUND/BUILDING', '0.0', '330.0', '400 S HOPE ST', '0', '34.0522', '-118.2538')
# ('1', '142015449', '03/01/2014 12:00:00 AM', '20', 'Olympic', 2015, '354', 'THEFT OF IDENTITY', '501.0', 'SINGLE FAMILY DWELLING', '0.0', '354.0', '100 N EDGEMONT ST', '0', '34.0728', '-118.2975')
# ('2', '140318666', '08/25/2014 12:00:00 AM', '3', 'Southwest', 392, '624', 'BATTERY - SIMPLE ASSAULT', '501.0', 'SINGLE FAMILY DWELLING', '400.0', '624.0', '4800 CRENSHAW BL', '0', '34.0', '-118.3308')
# ('3', '140207314', '03/05/2014 12:00:00 AM', '2', 'Rampart', 219, '354', 'THEFT OF IDENTITY', '218.0', 'BEAUTY/BARBER SHOP', '0.0', '354.0', '1300 W SUNSET BL', '0', '34.072', '-118.2508')
# ...

# %%
import pandas as pd
fore0 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/fore0.csv', index_col=False, delimiter = ',')
fore1 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/fore1.csv', index_col=False, delimiter = ',')
fore2 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/fore2.csv', index_col=False, delimiter = ',')
fore3 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/fore3.csv', index_col=False, delimiter = ',')
fore4 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/fore4.csv', index_col=False, delimiter = ',')
cri0 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/cri0.csv', index_col=False, delimiter = ',')
cri1 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/cri0.csv', index_col=False, delimiter = ',')
cri1 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/cri0.csv', index_col=False, delimiter = ',')
cri1 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/cri0.csv', index_col=False, delimiter = ',')
cri1 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/cri0.csv', index_col=False, delimiter = ',')
cri1 = pd.read_csv(r'Downloads/LA_Foreclosure_Rates_Analysis/cri0.csv', index_col=False, delimiter = ',')
